% %% [markdown]
% # Set gnuplot as default graphics toolkit

% %%
graphics_toolkit("gnuplot")
pkg load signal

% %% [markdown]
% # Problem 1

% %%
n = 0:9;
h = (1/2).^n;
h1 = (1.3).^n;
subplot(2, 1, 1)
stem(n, h, 'LineWidth', 2, '.', 'Markersize', 20)
legend('stable')
subplot(2, 1, 2)
stem(n, h1, 'LineWidth', 2, '.', 'Markersize', 20)
legend('Unstable')
drawnow

% %%
N = 10;
a = [1, 2];
b =[1, -3];
n = 0:N;
x =2.^n;
x_in = filtic(b, a, 1, 0);
y1 = filter(b, a, x, x_in);
plot(y1)

% %%
N = 10;
a = [1, 2];
b =[1, -3];
n = 0:N;
x =2.^n;
x_in = filtic(b, a, 1, 0);
y1 = filter(b, a, x, x_in);
plot(y1)

% %%
b = [1 2 3 4];
a = [4 3 2 1];
h = impz(b, a);
stem(h)

% %%
b = [1 2 3 4];
a = [4 3 2 1];
zplane(b, a)

% %%
b = [1 2 3 4];
a = [4 3 2 1];
[H, w] = freqz(b, a);
freqz(b, a)

% %%
x = [1, 2, 3, 4];  
h = [4, 3, 2];  

y = conv(x, h);  
n = 0:length(y)-1;  % Define the correct time index  

stem(n, y, 'filled');  
xlabel('n');  
ylabel('y[n]');  
title('Output Response of Discrete-Time System');  
grid on;
